# %% [markdown]
# # Retail Product Recognition System — Training (Colab)
#
# This notebook is intentionally thin: it only clones the repo, installs
# dependencies, and calls the training/evaluation pipeline that lives in
# `src/`. All the real logic (data loading, model architecture, training
# loop, evaluation) is in versioned `.py` files, not pasted into cells —
# so the same code that ran here also runs unchanged on a local machine
# or a server, and there is only one place to fix a bug.

# %%
# !git clone https://github.com/mohamedlotfy-dev/retail-product-recognition-system.git
# %cd retail-product-recognition-system
# !pip install -q -r requirements.txt

# %%
from src import train
train.main()

# %%
from src import evaluate
evaluate.main()

# %% [markdown]
# ## Download the trained artifacts
#
# After training, `models/product_recognition_model.keras`,
# `models/class_names.json`, and the plots under `outputs/` are what the
# Streamlit app needs. Either commit them to the repo (if small enough)
# or download them from the Colab file browser and place them locally
# under `models/` and `outputs/` before running `streamlit run app/app.py`.
